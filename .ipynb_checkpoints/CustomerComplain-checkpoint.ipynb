# %%
import pandas as pd
df = pd.read_csv('complaints.csv')

# %% [markdown]
# https://www.kaggle.com/vineetverma/clustering-bank-complaints

# %%
original = df

# %%
df.head()
# Out:
#   Date received                                            Product  \
# 0    2019-05-28  Credit reporting, credit repair services, or o...
# 1    2019-09-24                                    Debt collection
# 2    2019-09-19  Credit reporting, credit repair services, or o...
# 3    2019-11-08                                    Debt collection
# 4    2019-05-03  Credit reporting, credit repair services, or o...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting  Problem with a credit reporting company's inve...
# 1     I do not know                  Attempts to collect debt not owed
# 2  Credit reporting               Incorrect information on your report
# 3     I do not know                              Communication tactics
# 4  Credit reporting               Incorrect information on your report
#
#                                            Sub-issue  \
# 0  Their investigation did not fix an error on yo...
# 1                                  Debt is not yours
# 2                Information belongs to someone else
# 3                         Frequent or repeated calls
# 4                      Account information incorrect
#
#                         Consumer complaint narrative  \
# 0  Although I am checking for and addressing miss...
# 1  transworld systems inc. \nis trying to collect...
# 2                                                NaN
# 3  Over the past 2 weeks, I have been receiving e...
# 4                                                NaN
#
#                              Company public response  \
# 0                                                NaN
# 1                                                NaN
# 2  Company has responded to the consumer and the ...
# 3                                                NaN
# 4  Company has responded to the consumer and the ...
#
#                                   Company State ZIP code Tags  \
# 0                           EQUIFAX, INC.    GA    310XX  NaN
# 1                  TRANSWORLD SYSTEMS INC    FL    335XX  NaN
# 2     Experian Information Solutions Inc.    PA    15206  NaN
# 3           Diversified Consultants, Inc.    NC    275XX  NaN
# 4  TRANSUNION INTERMEDIATE HOLDINGS, INC.    OK    735XX  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web           2019-05-28
# 1           Consent provided           Web           2019-09-24
# 2       Consent not provided           Web           2019-09-20
# 3           Consent provided           Web           2019-11-08
# 4                        NaN      Referral           2019-05-03
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0          Closed with explanation              Yes                NaN
# 1          Closed with explanation              Yes                NaN
# 2  Closed with non-monetary relief              Yes                NaN
# 3          Closed with explanation              Yes                NaN
# 4          Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0       3255189
# 1       3384392
# 2       3379500
# 3       3433198
# 4       3231144

# %%
df = df[['Consumer complaint narrative','Product']]
df.shape
# Out:
# (1761388, 2)

# %%
df.groupby('Product').size().sort_values(ascending=False)
# Out:
# Product
# Credit reporting, credit repair services, or other personal consumer reports    203735
# Debt collection                                                                 122018
# Mortgage                                                                         68825
# Credit card or prepaid card                                                      42475
# Credit reporting                                                                 31588
# Student loan                                                                     26885
# Checking or savings account                                                      24687
# Credit card                                                                      18838
# Bank account or service                                                          14885
# Money transfer, virtual currency, or money service                               10653
# Vehicle loan or lease                                                            10322
# Consumer Loan                                                                     9473
# Payday loan, title loan, or personal loan                                         7968
# Payday loan                                                                       1746
# Money transfers                                                                   1497
# Prepaid card                                                                      1450
# Other financial service                                                            292
# Virtual currency                                                                    16
# dtype: int64

# %%
df.head()
# Out:
#                         Consumer complaint narrative  \
# 0  Although I am checking for and addressing miss...
# 1  transworld systems inc. \nis trying to collect...
# 2                                                NaN
# 3  Over the past 2 weeks, I have been receiving e...
# 4                                                NaN
#
#                                              Product
# 0  Credit reporting, credit repair services, or o...
# 1                                    Debt collection
# 2  Credit reporting, credit repair services, or o...
# 3                                    Debt collection
# 4  Credit reporting, credit repair services, or o...

# %%
df = df[df["Consumer complaint narrative"].notnull() == True]

# %%
df.shape
# Out:
# (597353, 2)

# %%
df["category_id"] = df["Product"].factorize()[0]

# %%
df
# Out:
#                               Consumer complaint narrative  \
# 0        Although I am checking for and addressing miss...
# 1        transworld systems inc. \nis trying to collect...
# 3        Over the past 2 weeks, I have been receiving e...
# 5        In XX/XX/2018, I discovered that my ex husband...
# 6        Previously, on XX/XX/XXXX, XX/XX/XXXX, and XX/...
# ...                                                    ...
# 1761383  I recieved a collections call from an unknown ...
# 1761384  On XXXX XXXX, 2015, I contacted XXXX XXXX, who...
# 1761385  I made a payment to CITI XXXX Credit Card on X...
# 1761386  cfbp i would Like to file a complaint on Exper...
# 1761387  My husband and I are in the middle of an FHA S...
#
#                                                    Product  category_id
# 0        Credit reporting, credit repair services, or o...            0
# 1                                          Debt collection            1
# 3                                          Debt collection            1
# 5        Credit reporting, credit repair services, or o...            0
# 6        Credit reporting, credit repair services, or o...            0
# ...                                                    ...          ...
# 1761383                                    Debt collection            1
# 1761384                                           Mortgage            5
# 1761385                                        Credit card            8
# 1761386                                   Credit reporting           12
# 1761387                                   Credit reporting           12
#
# [597353 rows x 3 columns]

# %%
df['Product'].unique()
# Out:
# array(['Credit reporting, credit repair services, or other personal consumer reports',
#        'Debt collection', 'Student loan',
#        'Money transfer, virtual currency, or money service',
#        'Vehicle loan or lease', 'Mortgage', 'Checking or savings account',
#        'Credit card or prepaid card', 'Credit card',
#        'Payday loan, title loan, or personal loan', 'Consumer Loan',
#        'Payday loan', 'Credit reporting', 'Other financial service',
#        'Bank account or service', 'Money transfers', 'Prepaid card',
#        'Virtual currency'], dtype=object)

# %%
category_id_df = df[['Product', 'category_id']].drop_duplicates().sort_values('category_id')
category_id_df
# Out:
#                                                   Product  category_id
# 0       Credit reporting, credit repair services, or o...            0
# 1                                         Debt collection            1
# 15                                           Student loan            2
# 20      Money transfer, virtual currency, or money ser...            3
# 25                                  Vehicle loan or lease            4
# 27                                               Mortgage            5
# 28                            Checking or savings account            6
# 88                            Credit card or prepaid card            7
# 249                                           Credit card            8
# 355             Payday loan, title loan, or personal loan            9
# 970                                         Consumer Loan           10
# 4141                                          Payday loan           11
# 56683                                    Credit reporting           12
# 85997                             Other financial service           13
# 104941                            Bank account or service           14
# 152828                                    Money transfers           15
# 251947                                       Prepaid card           16
# 598714                                   Virtual currency           17

# %%
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Product']].values)

# %%
category_to_id
# Out:
# {'Credit reporting, credit repair services, or other personal consumer reports': 0,
#  'Debt collection': 1,
#  'Student loan': 2,
#  'Money transfer, virtual currency, or money service': 3,
#  'Vehicle loan or lease': 4,
#  'Mortgage': 5,
#  'Checking or savings account': 6,
#  'Credit card or prepaid card': 7,
#  'Credit card': 8,
#  'Payday loan, title loan, or personal loan': 9,
#  'Consumer Loan': 10,
#  'Payday loan': 11,
#  'Credit reporting': 12,
#  'Other financial service': 13,
#  'Bank account or service': 14,
#  'Money transfers': 15,
#  'Prepaid card': 16,
#  'Virtual currency': 17}
