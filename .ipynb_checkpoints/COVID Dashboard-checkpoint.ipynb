# %%
import os
import pandas as pd
#os.getcwd()
#os.chdir('/Users/ronny/downloads')
df_confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df_death = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
df_recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
# fix wide data to proper dataframe using melt
df_confirmed = df_confirmed.melt(id_vars=['Province/State','Country/Region','Lat','Long'])
df_confirmed.columns = ['State','Country','Lat','Long','Date','Confirmed']

df_death = df_death.melt(id_vars=['Province/State','Country/Region','Lat','Long'])
df_death.columns = ['State','Country','Lat','Long','Date','Death']

df_recovered = df_recovered.melt(id_vars=['Province/State','Country/Region','Lat','Long'])
df_recovered.columns = ['State','Country','Lat','Long','Date','Recovered']

# %%
df = df_confirmed.join(df_death['Death']).join(df_recovered['Recovered'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
df[df['Country']=='Australia']
# Out:
#                                State    Country      Lat      Long       Date  \
# 8       Australian Capital Territory  Australia -35.4735  149.0124 2020-01-22
# 9                    New South Wales  Australia -33.8688  151.2093 2020-01-22
# 10                Northern Territory  Australia -12.4634  130.8456 2020-01-22
# 11                        Queensland  Australia -27.4698  153.0251 2020-01-22
# 12                   South Australia  Australia -34.9285  138.6007 2020-01-22
# ...                              ...        ...      ...       ...        ...
# 101567                    Queensland  Australia -27.4698  153.0251 2021-01-28
# 101568               South Australia  Australia -34.9285  138.6007 2021-01-28
# 101569                      Tasmania  Australia -42.8821  147.3272 2021-01-28
# 101570                      Victoria  Australia -37.8136  144.9631 2021-01-28
# 101571             Western Australia  Australia -31.9505  115.8605 2021-01-28
#
#         Confirmed  Death  Recovered
# 8               0      0        0.0
# 9               0      0        0.0
# 10              0      0        0.0
# 11              0      0        0.0
# 12              0      0        0.0
# ...           ...    ...        ...
# 101567       1308      6        NaN
# 101568        596      4        NaN
# 101569        234     13        NaN
# 101570      20448    820        NaN
# 101571        898      9        NaN
#
# [2984 rows x 8 columns]

# %%
plt.figure(figsize=(25, 10))

features = ['Confirmed', 'NewCases','NewDeath']


for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    chart = sns.barplot(x='Date',y=col,data=Country)    
    chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
    plt.title(col)

# %%
# create plots
plt.figure(figsize=(10,8))

for i in range(len(t)):
    plt.subplot(1,3,i+1)
    plt.imshow(x_test[t[i]].reshape(8,8))
    plt.title('Pred %s' %(pred[t[i]]) + ' Act %s' %(y_test[t[i]]))

# %%
country = ['US','United Kingdom']
features = ['Confirmed', 'NewCases','NewDeath']


for index,desc in enumerate(country):
    print(index,desc)
    for index, desc in enumerate(features):
        print(index,desc)
# Out:
# 0 US
# 0 Confirmed
# 1 NewCases
# 2 NewDeath
# 1 United Kingdom
# 0 Confirmed
# 1 NewCases
# 2 NewDeath

# %%
df[(df['Date']>start_date) & (df['Country']=='US')].groupby(['Date','Country']).sum()
# Out:
#                      Lat   Long  Confirmed   Death  Recovered
# Date       Country
# 2020-09-02 US       40.0 -100.0    6108200  186098     1219.0
# 2020-09-03 US       40.0 -100.0    6152285  187156      462.0
# 2020-09-04 US       40.0 -100.0    6202700  188116    88457.0
# 2020-09-05 US       40.0 -100.0    6245682  188890   418101.0
# 2020-09-06 US       40.0 -100.0    6276981  189303     1015.0
# ...                  ...    ...        ...     ...        ...
# 2021-01-24 US       40.0 -100.0   25147891  419251        0.0
# 2021-01-25 US       40.0 -100.0   25298986  421168        0.0
# 2021-01-26 US       40.0 -100.0   25445583  425252        0.0
# 2021-01-27 US       40.0 -100.0   25598061  429195        0.0
# 2021-01-28 US       40.0 -100.0   25766681  433195        0.0
#
# [149 rows x 5 columns]

# %%
Country
# Out:
#           Date Country   Lat   Long  Confirmed   Death  Recovered
# 0   2020-09-02      US  40.0 -100.0    6108200  186098     1219.0
# 1   2020-09-03      US  40.0 -100.0    6152285  187156      462.0
# 2   2020-09-04      US  40.0 -100.0    6202700  188116    88457.0
# 3   2020-09-05      US  40.0 -100.0    6245682  188890   418101.0
# 4   2020-09-06      US  40.0 -100.0    6276981  189303     1015.0
# ..         ...     ...   ...    ...        ...     ...        ...
# 144 2021-01-24      US  40.0 -100.0   25147891  419251        0.0
# 145 2021-01-25      US  40.0 -100.0   25298986  421168        0.0
# 146 2021-01-26      US  40.0 -100.0   25445583  425252        0.0
# 147 2021-01-27      US  40.0 -100.0   25598061  429195        0.0
# 148 2021-01-28      US  40.0 -100.0   25766681  433195        0.0
#
# [149 rows x 7 columns]

# %%
plt.figure(figsize=(25, 10))

start_date = '2020-12-01'
country = ['US','United Kingdom']
features = ['Confirmed', 'Death','Recovered']


fig = plt.subplots(2,3,figsize=(25,10))

for index1,desc1 in enumerate(country):
        Country = df[(df['Date']>start_date) & (df['Country']==desc1)].groupby(['Date','Country']).sum()
        Country.reset_index(inplace=True)
        for index2, desc2 in enumerate(features):
            
            plt.subplot(index1+1, len(features) , index2+1)
            print (index1+1,index2+1)
            chart = sns.barplot(x='Date',y=desc2,data=Country)    
            chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
            plt.title(desc1 + ' ' + desc2)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3

# %%
plt.subplot(2, len(features) , 1)

# %%
start_date = '2020-09-01'

# %%
#Country = df[(df['Date']>'2020/03/01') & (df['Country']=='Italy')]
import matplotlib.pyplot as plt
import seaborn as sns

start_date = '2020-12-01'

Country = df[(df['Date']>start_date) & (df['Country']=='US')].groupby(['Date','Country']).sum()
Country.reset_index(inplace=True)

Country = Country.sort_values(['Date'],ascending=True)     # sort values for cal purpose later on, use ascending otherwise you get negative numbers
Country['NewDeath']= Country[['Death']].diff()
Country['NewCases']= Country[['Confirmed']].diff()
Country['Mortality%']= Country['Death']/Country['Confirmed']*100
Country['Date'] = Country['Date'].dt.strftime('%d/%m/%Y')

fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(25,10))

chart = sns.barplot(x='Date',y='Confirmed',data=Country, ax=ax1)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
chart.set(title='USA Total Confirmed Cases')

chart = sns.barplot(x='Date',y='NewCases',data=Country, ax=ax2)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
chart.set(title='USA New Cases')

chart = sns.barplot(x='Date',y='NewDeath',data=Country, ax=ax3)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
chart.set(title='USA New Death')

plt.show()

# %%
#Country = df[(df['Date']>'2020/03/01') & (df['Country']=='Italy')]
import matplotlib.pyplot as plt
import seaborn as sns

Country = df[(df['Date']>'2020/03/01') & (df['Country']=='United Kingdom')].groupby(['Date','Country']).sum()
Country.reset_index(inplace=True)

Country = Country.sort_values(['Date'],ascending=True)     # sort values for cal purpose later on, use ascending otherwise you get negative numbers
Country['NewDeath']= Country[['Death']].diff()
Country['NewCases']= Country[['Confirmed']].diff()
Country['Mortality%']= Country['Death']/Country['Confirmed']*100
Country['Date'] = Country['Date'].dt.strftime('%d/%m/%Y')

fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(25,10))

chart = sns.barplot(x='Date',y='Confirmed',data=Country, ax=ax1)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
chart.set(title='UK Total Confirmed Cases')

chart = sns.barplot(x='Date',y='NewCases',data=Country, ax=ax2)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
chart.set(title='UK New Cases')

chart = sns.barplot(x='Date',y='NewDeath',data=Country, ax=ax3)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
chart.set(title='UK New Death')

plt.show()

# %%
#Country = df[(df['Date']>'2020/03/01') & (df['Country']=='Italy')]
import matplotlib.pyplot as plt
import seaborn as sns

Country = df[(df['Date']>'2020/03/01') & (df['Country']=='Australia')].groupby(['Date','Country']).sum()
Country.reset_index(inplace=True)

Country = Country.sort_values(['Date'],ascending=True)     # sort values for cal purpose later on, use ascending otherwise you get negative numbers
Country['NewDeath']= Country[['Death']].diff()
Country['NewCases']= Country[['Confirmed']].diff()
Country['Mortality%']= Country['Death']/Country['Confirmed']*100
Country['Date'] = Country['Date'].dt.strftime('%d/%m/%Y')

fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(25,10))

chart = sns.barplot(x='Date',y='Confirmed',data=Country, ax=ax1)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=9)
chart.set(title='AUS Total Confirmed Cases')

chart = sns.barplot(x='Date',y='NewCases',data=Country, ax=ax2)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=9)
chart.set(title='AUS New Cases')

chart = sns.barplot(x='Date',y='NewDeath',data=Country, ax=ax3)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=9)
chart.set(title='AUS New Death')

plt.show()

# %%
#Country = df[(df['Date']>'2020/03/01') & (df['Country']=='Italy')]
import matplotlib.pyplot as plt
import seaborn as sns

Country = df[(df['Date']>'2020/03/01') & (df['Country']=='Indonesia')].groupby(['Date','Country']).sum()
Country.reset_index(inplace=True)

Country = Country.sort_values(['Date'],ascending=True)     # sort values for cal purpose later on, use ascending otherwise you get negative numbers
Country['NewDeath']= Country[['Death']].diff()
Country['NewCases']= Country[['Confirmed']].diff()
Country['Mortality%']= Country['Death']/Country['Confirmed']*100
Country['Date'] = Country['Date'].dt.strftime('%d/%m/%Y')

fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(25,10))

chart = sns.barplot(x='Date',y='Confirmed',data=Country, ax=ax1)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
chart.set(title='IND Total Confirmed Cases')

chart = sns.barplot(x='Date',y='NewCases',data=Country, ax=ax2)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
chart.set(title='IND New Cases')

chart = sns.barplot(x='Date',y='NewDeath',data=Country, ax=ax3)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90,horizontalalignment='left',fontsize=7)
chart.set(title='IND New Death')

plt.show()
