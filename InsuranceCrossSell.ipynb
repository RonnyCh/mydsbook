# %% [markdown]
# For data definition and further information please check the link https://www.kaggle.com/anmolkumar/health-insurance-cross-sell-prediction

# %%
import pandas as pd

train = pd.read_csv("../mydsbook/DataInsurance/train.csv")
test = pd.read_csv("../mydsbook/DataInsurance/test.csv")

# %%
import seaborn as sns

sns.countplot(x='Gender',data=train)

# %%
train.groupby(['Region_Code','Response']).count().sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-7afc767199ef> in <module>
# ----> 1 train.groupby(['Region_Code','Response']).count().sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
print ('train has {} rows and test has {} rows'.format(train.shape[0],test.shape[0]))
# Out:
# train has 381109 rows and test has 127037 rows

# %%
train = train.drop(['id'],axis=1)
train.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0    Male   44                1         28.0                   0   > 2 Years
# 1    Male   76                1          3.0                   0    1-2 Year
# 2    Male   47                1         28.0                   0   > 2 Years
# 3    Male   21                1         11.0                   1    < 1 Year
# 4  Female   29                1         41.0                   1    < 1 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         40454.0                  26.0      217         1
# 1             No         33536.0                  26.0      183         0
# 2            Yes         38294.0                  26.0       27         1
# 3             No         28619.0                 152.0      203         0
# 4             No         27496.0                 152.0       39         0

# %%
train['Channel']=0
train.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0    Male   44                1         28.0                   0   > 2 Years
# 1    Male   76                1          3.0                   0    1-2 Year
# 2    Male   47                1         28.0                   0   > 2 Years
# 3    Male   21                1         11.0                   1    < 1 Year
# 4  Female   29                1         41.0                   1    < 1 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response  \
# 0            Yes         40454.0                  26.0      217         1
# 1             No         33536.0                  26.0      183         0
# 2            Yes         38294.0                  26.0       27         1
# 3             No         28619.0                 152.0      203         0
# 4             No         27496.0                 152.0       39         0
#
#    Channel
# 0        0
# 1        0
# 2        0
# ...

# %%
import seaborn as sns
penguins = sns.load_dataset("penguins")
sns.histplot(data=penguins, x="flipper_length_mm")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8cd2c76815cc> in <module>
#       1 import seaborn as sns
#       2 penguins = sns.load_dataset("penguins")
# ----> 3 sns.histplot(data=penguins, x="flipper_length_mm")
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
penguins = sns.load_dataset("penguins")
sns.distplot(penguins, x="flipper_length_mm")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-185-528a92756433> in <module>
#       1 penguins = sns.load_dataset("penguins")
# ----> 2 sns.distplot(penguins, x="flipper_length_mm")
#
# TypeError: distplot() got an unexpected keyword argument 'x'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#df = sns.load_dataset('flights')
#df.head()

fig, (ax1,ax2) = plt.subplots(2,1,figsize=(17,7))
fig.suptitle('Region Codes', fontsize=16)


chart1 = sns.countplot(x='Region_Code',data=train,ax=ax1)
chart1.set(title='Count Plot')
chart1.set(xLabel='Year')
chart1.set(yLabel='Passenger')
chart1.set_xticklabels(chart1.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '0.0'),
#  Text(0, 0, '1.0'),
#  Text(0, 0, '2.0'),
#  Text(0, 0, '3.0'),
#  Text(0, 0, '4.0'),
#  Text(0, 0, '5.0'),
#  Text(0, 0, '6.0'),
#  Text(0, 0, '7.0'),
#  Text(0, 0, '8.0'),
#  Text(0, 0, '9.0'),
#  Text(0, 0, '10.0'),
#  Text(0, 0, '11.0'),
#  Text(0, 0, '12.0'),
#  Text(0, 0, '13.0'),
#  Text(0, 0, '14.0'),
#  Text(0, 0, '15.0'),
#  Text(0, 0, '16.0'),
#  Text(0, 0, '17.0'),
#  Text(0, 0, '18.0'),
#  Text(0, 0, '19.0'),
#  Text(0, 0, '20.0'),
#  Text(0, 0, '21.0'),
#  Text(0, 0, '22.0'),
#  Text(0, 0, '23.0'),
#  Text(0, 0, '24.0'),
#  Text(0, 0, '25.0'),
#  Text(0, 0, '26.0'),
#  Text(0, 0, '27.0'),
#  Text(0, 0, '28.0'),
#  Text(0, 0, '29.0'),
#  Text(0, 0, '30.0'),
#  Text(0, 0, '31.0'),
#  Text(0, 0, '32.0'),
#  Text(0, 0, '33.0'),
#  Text(0, 0, '34.0'),
#  Text(0, 0, '35.0'),
#  Text(0, 0, '36.0'),
#  Text(0, 0, '37.0'),
#  Text(0, 0, '38.0'),
#  Text(0, 0, '39.0'),
#  Text(0, 0, '40.0'),
#  Text(0, 0, '41.0'),
#  Text(0, 0, '42.0'),
# ...

# %%
train.loc[train['Policy_Sales_Channel']<40,['Channel']]=1
train.loc[(train['Policy_Sales_Channel']>=40)&(train['Policy_Sales_Channel']<80),['Channel']]=2
train.loc[(train['Policy_Sales_Channel']>=80)&(train['Policy_Sales_Channel']<130),['Channel']]=3
train.loc[train['Policy_Sales_Channel']>=130,['Channel']]=4

# %%
train['Channel'].drop_duplicates()
# Out:
# 0     1
# 3     4
# 10    3
# 96    2
# Name: Channel, dtype: int64

# %%
train.groupby(['Channel','Response']).size()
# Out:
# Channel  Response
# 1        0            80072
#          1            18319
# 2        0             3880
#          1              561
# 3        0            71363
#          1            16117
# 4        0           179084
#          1            11713
# dtype: int64

# %%
df[df['Response']==1].groupby('Policy_Sales_Channel').count()
# Out:
#                         id  Gender   Age  Driving_License  Region_Code  \
# Policy_Sales_Channel
# 1.0                     35      35    35               35           35
# 2.0                      1       1     1                1            1
# 3.0                    159     159   159              159          159
# 4.0                    102     102   102              102          102
# 7.0                    182     182   182              182          182
# ...                    ...     ...   ...              ...          ...
# 157.0                 1794    1794  1794             1794         1794
# 158.0                  135     135   135              135          135
# 159.0                    1       1     1                1            1
# 160.0                  475     475   475              475          475
# 163.0                  880     880   880              880          880
#
#                       Previously_Insured  Vehicle_Age  Vehicle_Damage  \
# ...

# %%
boxplot = df.boxplot(column=['Vintage'])

# %%
df.groupby('Response').count()
# Out:
#               id  Gender     Age  Driving_License  Region_Code  \
# Response
# 0         334399  334399  334399           334399       334399
# 1          46710   46710   46710            46710        46710
#
#           Previously_Insured  Vehicle_Age  Vehicle_Damage  Annual_Premium  \
# Response
# 0                     334399       334399          334399          334399
# 1                      46710        46710           46710           46710
#
#           Policy_Sales_Channel  Vintage
# Response
# 0                       334399   334399
# 1                        46710    46710

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

sns.countplot(x="Vehicle_Damage", data=train, hue='Response', palette="colorblind") # refer ax to which col and row to go to (start from 0 base)
#chart1.set(title='Tips Count Plot')

# %%
sns.boxplot(y="Age", x='Gender', data=train)
#chart2.set(title='Tips Box Plot')

# %%
import seaborn as sns
sns.set(style="ticks")
sns.set_palette("rainbow")

sns.pairplot(train, hue="Response")
# Out:
# C:\Users\m118954\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\m118954\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\m118954\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-daee7b341b35> in <module>
#       3 sns.set_palette("rainbow")
#       4
# ----> 5 sns.pairplot(train, hue="Response")
#
# ...
